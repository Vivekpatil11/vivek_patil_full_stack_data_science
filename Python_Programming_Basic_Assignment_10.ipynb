# %%
#1
lst=[1,2,3,4,5,6,7]
res=0
for i in lst:
    res+=i
print(res)
# Out:
# 28

# %%
#2
lst=[1,2,3,4,5,6,7,8]
res=1
for i in lst:
    res*=i
print(res)
# Out:
# 40320

# %%
#3
lst=[5,2,7,2,3,5,3,1]
res=lst[0]
for i in range(1,len(lst)):
    if(res>lst[i]):
        res=lst[i]
print(res)
# Out:
# 1

# %%
#4
lst=[5,2,7,2,3,5,3,1]
res=lst[0]
for i in range(1,len(lst)):
    if(res<lst[i]):
        res=lst[i]
print(res)
# Out:
# 7

# %%
#5
lst=[1,8,4,6,3,22,15,10,354,56]
print(sorted(lst)[-2])
# Out:
# 56

# %%
#6
n=6
lst=[1,4,3,60,3,45,32,423,2423,56]
print(sorted(lst)[-n])
# Out:
# 32

# %%
#7
lst=[1,4,3,60,3,45,32,423,2423,56]
for i in lst:
    if(i%2==0):
        print(i)
# Out:
# 4
# 60
# 32
# 56

# %%
#8
lst=[1,4,3,60,3,45,32,423,2423,56]
for i in lst:
    if(i%2==1):
        print(i)
# Out:
# 1
# 3
# 3
# 45
# 423
# 2423

# %%
#9
lst=[[1,2,3],[4,1,3],[12,56],[]]
for i in lst:
    if(type(i) is list and len(i)==0):
        lst.remove(i)
print(lst)
# Out:
# [[1, 2, 3], [4, 1, 3], [12, 56]]

# %%
#10
lst=[1,4,3,60,3,45,32,423,2423,56]
lst_cop=lst[:]
print(lst_cop)
# Out:
# [1, 4, 3, 60, 3, 45, 32, 423, 2423, 56]

# %%
#11
lst=[1,4,3,60,3,45,1,32,423,1,2423,56,1,]
ele=1
res=0
for i in lst:
    if(i==1):
        res+=1
print(res)
# Out:
# 4
