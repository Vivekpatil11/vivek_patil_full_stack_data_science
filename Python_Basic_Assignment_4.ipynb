# %%
1. A list is a data structure in Python that is a mutable, or changeable, ordered sequence of elements. Each element or value 
that is inside of a list is called an item.

# %%
#2
spam=[2,4,6,8,10]
spam[2]='hello'

# %%
spam=['a','b','c','d']

# %%
#3
spam[int(int('3' * 2) / 11)]
# Out:
# 'd'

# %%
#4
spam[-1]
# Out:
# 'd'

# %%
#5
spam[-2]
# Out:
# 'c'

# %%
bacon=[3.14,'cat',11,'cat',True]

# %%
#6
bacon.index('cat')
# Out:
# 1

# %%
#7
bacon.append(99)
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %%
#8
bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %%
9. elements of one list are added at the end of another list.
* is the list replication operator, repeating a single string however many times you would like through the integer you provide

# %%
10. append method inserts the elements at last where as insert method inserts the element at the given position

# %%
11. pop : it removes the element using the index of the element
remove : It removes the element using the element

# %%
12. The values that make up a list are called its elements. Lists are similar to strings, which are ordered collections of 
characters, except that the elements of a list can have any type and for any one list, the items can be of different types. 
As we said above, the elements of a list don't have to be the same type.

# %%
13. The key difference between the tuples and lists is that while the tuples are immutable objects the lists are mutable.

# %%
#14
a=(14,)

# %%
a
# Out:
# (14,)

# %%
type(a)
# Out:
# tuple

# %%
#15
a=(1,2,3,4,5)
b=['a','b','c','d','e']
print(list(a))
print(tuple(b))
# Out:
# [1, 2, 3, 4, 5]
# ('a', 'b', 'c', 'd', 'e')

# %%
16 The whole string is divided to each character and store in the list

# %%
a="contain"
list(a)
# Out:
# ['c', 'o', 'n', 't', 'a', 'i', 'n']

# %%
import copy
a=[1,2,3,4,5]
c=copy.deepcopy(a)

# %%
c[2]=10
print(c)
print(a)
# Out:
# [1, 2, 10, 4, 5]
# [1, 2, 3, 4, 5]

# %%
a=[1,2,[3,6],4,5]
b=copy.copy(a)
b[2][0]=9
print(b)
print(a)
# Out:
# [1, 2, [9, 6], 4, 5]
# [1, 2, [9, 6], 4, 5]
