# %%
#1
print("Hello Python")
# Out:
# Hello Python

# %%
#2
print(5+3)
print(10//5)
# Out:
# 8
# 2

# %%
#3
breadth=10
length=10
area=breadth*length/2
print("Area of the traiangle is",area)
# Out:
# Area of the traiangle is 50.0

# %%
#4
a=10
b=5
print("Before Swaping",a,b)
temp=a
a=b
b=temp
print("After Swaping ",a,b)
# Out:
# Before Swaping 10 5
# After Swaping  5 10

# %%
#5
import random
print(random.randint(5,10))
# Out:
# 9
