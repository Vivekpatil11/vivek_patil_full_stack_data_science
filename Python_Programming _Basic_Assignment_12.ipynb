# %%
#1
a={'a':1,'b':2,'c':3,'d':2,'e':4,'f':1,'g':5,'h':5}
b=list(a.values())
for i in b:
    if(b.count(i)==1):
        print(i)
# Out:
# 3
# 4

# %%
#2
a={'a':1,'b':2,'c':3,'d':2,'e':4,'f':1,'g':5,'h':5}
res=0
for i in a:
    res+=a[i]
print(res)
# Out:
# 23

# %%
#3
a={'a':1,'b':2,'c':3}
b={'d':2,'e':4,'f':1}
b.update(a)
print(b)
# Out:
# {'d': 2, 'e': 4, 'f': 1, 'a': 1, 'b': 2, 'c': 3}

# %%
#4
test_dict = {'month' : [1, 2, 3],'name' : ['Jan', 'Feb', 'March']}
res=dict(zip(test_dict['month'],test_dict['name']))
print(res)
# Out:
# {1: 'Jan', 2: 'Feb', 3: 'March'}

# %%
#5
from collections import OrderedDict
dic1 = OrderedDict([('A', '100'), ('B', '200'), ('C', '300')])
insrt = OrderedDict([("D", '400')])
final = OrderedDict(list(insrt.items()) + list(dic1.items()))
print(final)
# Out:
# OrderedDict([('D', '400'), ('A', '100'), ('B', '200'), ('C', '300')])

# %%
#6
from collections import OrderedDict
def check_order(my_input, my_pattern):
   my_dict = OrderedDict.fromkeys(my_input)
   pattern_length = 0
   for key,value in my_dict.items():
      if (key == my_pattern[pattern_length]):
         pattern_length = pattern_length + 1

      if (pattern_length == (len(my_pattern))):
         return 'The order of pattern is correct'

   return 'The order of pattern is incorrect'

my_input = 'engineering'
input_pattern = 'er'
print(check_order(my_input,input_pattern))
# Out:
# The order of pattern is correct

# %%
#7
nums = [1,1,7,3,5,3,2,9,5,1,3,2,2,2,2,2,9]
def count(num_list):
    count_dict = {}
    for num in num_list:
        count_dict[num] = num_list.count(num)
    return dict(sorted(count_dict.items(), key=lambda x:x[1]))
print(count(nums))
# Out:
# {7: 1, 5: 2, 9: 2, 1: 3, 3: 3, 2: 6}

# %%
nums = [1,1,7,3,5,3,2,9,5,1,3,2,2,2,2,2,9]
def count(num_list):
    count_dict = {}
    for num in num_list:
        count_dict[num] = num_list.count(num)
    return dict(sorted(count_dict.items(), key=lambda x:x[0]))
print(count(nums))
# Out:
# {1: 3, 2: 6, 3: 3, 5: 2, 7: 1, 9: 2}
