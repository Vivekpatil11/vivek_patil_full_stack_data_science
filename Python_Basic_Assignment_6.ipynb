# %%
1. To insert characters that are illegal in a string, use an escape character. An escape character is a backslash \ followed 
by the character you want to insert.

# %%
2. n stands for the next line where as t stands for the tab space

# %%
3. By using the 2 blackslash continuosly "\\"

# %%
4. Because the string are mentioned using the double quotes so the compailer will not consider as the strings end so escape 
character is not required for example

# %%
a="vivek's"

# %%
a='vivek\'s'

# %%
5. Using the triple quotes. For example

# %%
a="""vivek
patil """

# %%
#6
print('Hello, world!'[1])
print('Hello, world!'[0:5])
print('Hello, world!'[:5])
print('Hello, world!'[3:])
# Out:
# e
# Hello
# Hello
# lo, world!

# %%
#7
print("Hello".upper())
print('Hello'.upper().isupper())
print('Hello'.upper().lower())
# Out:
# HELLO
# True
# hello

# %%
#8
print('Remember, remember, the fifth of july.'.split())
print('-'.join('There can only one.'.split()))
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'july.']
# There-can-only-one.

# %%
9. Center : This function center aligns the string according to the width specified and fills remaining space of line with 
blank space if ‘ fillchr ‘ argument is not passed.
Left : This function left aligns the string according to the width specified and fills remaining space of line with blank 
space if ‘ fillchr ‘ argument is not passed.
Right : This function right aligns the string according to the width specified and fills remaining space of line with blank 
space if ‘ fillchr ‘ argument is not passed.

# %%
10. trimStart() or trimEnd() method used to remove the whitespaces from the string at the beginning and the end.
