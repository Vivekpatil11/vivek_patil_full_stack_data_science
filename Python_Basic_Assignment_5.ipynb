# %%
#1
empty_dic={}

# %%
type(empty_dic)
# Out:
# dict

# %%
#2
did={'foo':42}
list(did.values())
# Out:
# [42]

# %%
#so the value of the dictionary is 42

# %%
3. A list is an ordered sequence of objects, whereas dictionaries are unordered sets. However, the main difference is that 
items in dictionaries are accessed via keys and not via their position.

# %%
4. key error

# %%
5. Both the statements will check whether the 'cat' keyword exist in the dictionary or not.

# %%
6. 'cat' in spam check whether the keyword 'cat' exist in the dictionary as keyword or not where as 'cat' in spam.values()
checks whether the 'cat' word is present as value in the dictionary

# %%
7. spam.setdefault('color', 'black')

# %%
8. pprint.pprint()
